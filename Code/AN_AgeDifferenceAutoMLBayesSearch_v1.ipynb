# %% [markdown]
# # Age Difference: XGB Experiment based on 59 Variables 1513k Rows 14 Waves

# %%
# %pwd
# Out:
# '/mnt/d/OneDrive - Kyushu University/ESG09_Article/Code'

# %%
# %cd ..
# Out:
# /mnt/d/OneDrive - Kyushu University/ESG09_Article
# /home/linux/anaconda3/envs/automl/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## Import Package

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from joblib import dump
import os 
import pandas as pd
import random
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, KFold
from skopt import BayesSearchCV
from skopt.space import Real, Integer
import xgboost as xgb

# %% [markdown]
# ## Load and Make Datasets

# %%
Df_Filename = os.path.join("Data", "GallupWB_Ml64var1911k14wave_v1.parquet")

# %%
Df = pd.read_parquet(Df_Filename)

# %%
Df.shape
# Out:
# (1911212, 64)

# %%
Df.columns
# Out:
# Index(['wave', 'INCOME_2', 'Cantril_ladder', 'Health_disable', 'Relative_have',
#        'Living_standard_change', 'Enough_food', 'Enough_shelter',
#        'Well_rested', 'Respected', 'Smile', 'Interesting_thing', 'Enjoyment',
#        'Physical_pain', 'Worry', 'Sadness', 'Stress', 'Anger',
#        'City_satisficied', 'Economic_change', 'Goodtime_job', 'Sat_pubtran',
#        'Sat_road', 'Sat_edu', 'Sat_qualityair', 'Sat_qualitywater',
#        'Sat_healthcare', 'Sat_affhouse', 'Sat_oppofriend', 'Good_minorities',
#        'Good_gayles', 'Good_immigrants', 'Donated', 'Volunteer',
#        'Help_stranger', 'Voice_official', 'Local_police', 'Safety_walk',
#        'Stolen', 'Assualted', 'Religion_importance', 'Children_respected',
#        'Children_learn', 'Women_respected', 'Sat_dealpoor', 'Sat_perserveenv',
#        'Freedom_chooselife', 'Conf_military', 'Conf_judicial',
#        'Conf_government', 'Conf_financial', 'Conf_honestyelections',
#        'Freedom_media', 'Corruption_business', 'Corruption_government',
#        'Performance_leadership', 'Gender_female', 'Age', 'Marital_status',
#        'Employment', 'Children_under15', 'Feeling_income', 'Income_level',
#        'COUNTRY_ISO3'],
#       dtype='object')

# %% [markdown]
# ### Check the Difference between Age Group

# %%
young_cantrilladder = Df.loc[Df['Age']<=40, 'Cantril_ladder']

# %%
young_cantrilladder.mean()
# Out:
# 5.46157389538526

# %%
middle_cantrilladder = Df.loc[(Df['Age']>40)&(Df['Age']<=65), 'Cantril_ladder']

# %%
middle_cantrilladder.mean()
# Out:
# 5.546090633585152

# %%
old_cantrilladder = Df.loc[Df['Age']>65, 'Cantril_ladder']

# %%
old_cantrilladder.mean()
# Out:
# 5.727577206476798

# %%
t_stat, p_value = stats.ttest_ind(young_cantrilladder, middle_cantrilladder)

# %%
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -22.394787205917154, P-value: 4.592108979551354e-111

# %%
t_stat, p_value = stats.ttest_ind(young_cantrilladder, old_cantrilladder)

# %%
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -46.54255508076877, P-value: 0.0

# %%
t_stat, p_value = stats.ttest_ind(middle_cantrilladder, old_cantrilladder)

# %%
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -30.141361019016323, P-value: 1.760592592819179e-199

# %% [markdown]
# ### Shuffle Conversion

# %%
Df = Df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
Df['COUNTRY_ISO3'] = Df['COUNTRY_ISO3'].astype('category')

# %%
Df.isna().any().any()
# Out:
# False

# %% [markdown]
# ### Df_young

# %%
Df_young = Df.loc[Df['Age']<=40, :].drop(columns=['Age'])

# %%
Df_young.shape
# Out:
# (1031174, 63)

# %%
y_train, y_test = train_test_split(Df_young, test_size=0.1, random_state=42)

# %% [markdown]
# ### Df_middle

# %%
Df_middle = Df.loc[(Df['Age']>40)&(Df['Age']<=65), :].drop(columns=['Age'])

# %%
Df_middle.shape
# Out:
# (663573, 63)

# %%
m_train, m_test = train_test_split(Df_middle, test_size=0.1, random_state=42)

# %% [markdown]
# ### Df_old

# %%
Df_old = Df.loc[Df['Age']>65, :].drop(columns=['Age'])

# %%
Df_old.shape
# Out:
# (216465, 63)

# %%
o_train, o_test = train_test_split(Df_old, test_size=0.1, random_state=42)

# %% [markdown]
# ## AutoML Test

# %% [markdown]
# ### Young Model

# %%
label = 'Cantril_ladder'

# %%
y_predictor = TabularPredictor(label=label, eval_metric='r2', problem_type = 'regression').fit(y_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240622_104037"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.9.19
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          10
# Memory Avail:       120.26 GB / 125.66 GB (95.7%)
# Disk Space Avail:   190.77 GB / 1863.00 GB (10.2%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (928056 samples, 469.61 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240622_104037"
# Train Data Rows:    928056
# Train Data Columns: 62
# Label Column:       Cantril_ladder
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    123156.15 MB
# 	Train Data (Original)  Memory Usage: 433.69 MB (0.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 53 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) :  1 | ['COUNTRY_ISO3']
# 		('float', [])    : 60 | ['INCOME_2', 'Health_disable', 'Relative_have', 'Living_standard_change', 'Enough_food', ...]
# 		('int', [])      :  1 | ['wave']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  :  1 | ['COUNTRY_ISO3']
# 		('float', [])     :  7 | ['INCOME_2', 'Living_standard_change', 'Economic_change', 'Marital_status', 'Employment', ...]
# 		('int', [])       :  1 | ['wave']
# 		('int', ['bool']) : 53 | ['Health_disable', 'Relative_have', 'Enough_food', 'Enough_shelter', 'Well_rested', ...]
# 	2.4s = Fit runtime
# 	62 features in original data used to generate 62 features in processed data.
# 	Train Data (Processed) Memory Usage: 105.32 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 2.61s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 918775, Val Rows: 9281
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.1201	 = Validation score   (r2)
# 	1.32s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.0677	 = Validation score   (r2)
# 	1.35s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's l2: 3.82052	valid_set's r2: 0.332089
# [2000]	valid_set's l2: 3.80369	valid_set's r2: 0.335032
# [3000]	valid_set's l2: 3.79316	valid_set's r2: 0.336872
# [4000]	valid_set's l2: 3.78847	valid_set's r2: 0.337692
# [5000]	valid_set's l2: 3.78704	valid_set's r2: 0.337942
# [6000]	valid_set's l2: 3.78725	valid_set's r2: 0.337906
# [7000]	valid_set's l2: 3.78552	valid_set's r2: 0.338207
# [8000]	valid_set's l2: 3.78802	valid_set's r2: 0.337772
# [9000]	valid_set's l2: 3.79007	valid_set's r2: 0.337412
# 	0.3383	 = Validation score   (r2)
# 	195.89s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's l2: 3.77369	valid_set's r2: 0.340277
# [2000]	valid_set's l2: 3.7687	valid_set's r2: 0.341149
# [3000]	valid_set's l2: 3.76368	valid_set's r2: 0.342026
# [4000]	valid_set's l2: 3.76038	valid_set's r2: 0.342603
# [5000]	valid_set's l2: 3.76339	valid_set's r2: 0.342076
# 	0.3427	 = Validation score   (r2)
# 	116.05s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	0.2956	 = Validation score   (r2)
# 	557.06s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.3397	 = Validation score   (r2)
# 	834.13s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	0.2696	 = Validation score   (r2)
# 	504.99s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# Matplotlib is building the font cache; this may take a moment.
# 	0.3335	 = Validation score   (r2)
# 	356.84s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.3351	 = Validation score   (r2)
# 	83.84s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.3096	 = Validation score   (r2)
# 	569.7s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's l2: 3.74666	valid_set's r2: 0.345001
# [2000]	valid_set's l2: 3.73805	valid_set's r2: 0.346507
# 	0.3471	 = Validation score   (r2)
# 	77.32s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBMLarge': 0.56, 'LightGBMXT': 0.12, 'XGBoost': 0.12, 'CatBoost': 0.08, 'NeuralNetFastAI': 0.08, 'LightGBM': 0.04}
# 	0.3484	 = Validation score   (r2)
# 	0.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3314.43s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 6428.1 rows/s (9281 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240622_104037")

# %%
y_predictor.evaluate(y_test, silent=True)
# Out:
# {'r2': 0.35417279016135605,
#  'root_mean_squared_error': -1.9230941547753664,
#  'mean_squared_error': -3.698291128131181,
#  'mean_absolute_error': -1.4517836237657942,
#  'pearsonr': 0.5952217488143414,
#  'median_absolute_error': -1.1045880317687988}

# %%
y_predictor.leaderboard(y_test)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0   WeightedEnsemble_L2    0.354173   0.348362          r2       17.521234
# 1              LightGBM    0.352381   0.342718          r2        3.990122
# 2         LightGBMLarge    0.352111   0.347091          r2        2.656945
# 3            LightGBMXT    0.347860   0.338331          r2        7.703820
# 4              CatBoost    0.345274   0.339741          r2        0.338550
# 5               XGBoost    0.339657   0.335078          r2        2.206861
# 6       NeuralNetFastAI    0.338254   0.333492          r2        0.615572
# 7        NeuralNetTorch    0.310650   0.309606          r2        0.278528
# 8       RandomForestMSE    0.296504   0.295558          r2        4.513988
# 9         ExtraTreesMSE    0.273831   0.269597          r2        4.101200
# 10       KNeighborsUnif    0.133108   0.120082          r2        1.047801
# 11       KNeighborsDist    0.080518   0.067670          r2        1.054540
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 0        1.443814  1664.146551                 0.009365
# 1        0.315581   116.046508                 3.990122
# 2        0.209865    77.320442                 2.656945
# 3        0.661076   195.893915                 7.703820
# 4        0.023228   834.129205                 0.338550
# 5        0.180854    83.837374                 2.206861
# 6        0.052697   356.843449                 0.615572
# 7        0.021147   569.700333                 0.278528
# 8        0.142281   557.057962                 4.513988
# 9        0.124419   504.989644                 4.101200
# 10       0.066939     1.322327                 1.047801
# 11       0.066968     1.345955                 1.054540
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000513           0.075659            2       True
# 1                 0.315581         116.046508            1       True
# 2                 0.209865          77.320442            1       True
# 3                 0.661076         195.893915            1       True
# 4                 0.023228         834.129205            1       True
# 5                 0.180854          83.837374            1       True
# 6                 0.052697         356.843449            1       True
# 7                 0.021147         569.700333            1       True
# 8                 0.142281         557.057962            1       True
# 9                 0.124419         504.989644            1       True
# 10                0.066939           1.322327            1       True
# 11                0.066968           1.345955            1       True
#
#     fit_order
# 0          12
# 1           4
# 2          11
# 3           3
# 4           6
# 5           9
# 6           8
# 7          10
# 8           5
# 9           7
# 10          1
# 11          2

# %%
for key in y_predictor.info()['model_info'].keys():
    print(y_predictor.info()['model_info'][key]['name'])
    print(y_predictor.info()['model_info'][key]['val_score'])
    print(y_predictor.info()['model_info'][key]['hyperparameters'])
    print("--------------------")
# Out:
# KNeighborsUnif
# 0.1200818037315341
# {'weights': 'uniform'}
# --------------------
# KNeighborsDist
# 0.0676703671566482
# {'weights': 'distance'}
# --------------------
# LightGBMXT
# 0.33833092946293963
# {'learning_rate': 0.05, 'extra_trees': True}
# --------------------
# LightGBM
# 0.34271758696507315
# {'learning_rate': 0.05}
# --------------------
# RandomForestMSE
# 0.29555838165620585
# {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# --------------------
# CatBoost
# 0.3397405292008704
# {'iterations': 10000, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'R2'}
# --------------------
# ExtraTreesMSE
# 0.269596601021037
# {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# --------------------
# NeuralNetFastAI
# 0.33349214047479403
# {'layers': None, 'emb_drop': 0.1, 'ps': 0.1, 'bs': 'auto', 'lr': 0.01, 'epochs': 'auto', 'early.stopping.min_delta': 0.0001, 'early.stopping.patience': 20, 'smoothing': 0.0}
# --------------------
# XGBoost
# 0.3350780048485955
# {'n_estimators': 10000, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'reg:squarederror', 'booster': 'gbtree'}
# --------------------
# NeuralNetTorch
# 0.3096057848716056
# {'num_epochs': 500, 'epochs_wo_improve': 20, 'activation': 'relu', 'embedding_size_factor': 1.0, 'embed_exponent': 0.56, 'max_embedding_dim': 100, 'y_range': None, 'y_range_extend': 0.05, 'dropout_prob': 0.1, 'optimizer': 'adam', 'learning_rate': 0.0003, 'weight_decay': 1e-06, 'proc.embed_min_categories': 4, 'proc.impute_strategy': 'median', 'proc.max_category_levels': 100, 'proc.skew_threshold': 0.99, 'use_ngram_features': False, 'num_layers': 4, 'hidden_size': 128, 'max_batch_size': 512, 'use_batchnorm': False, 'loss_function': 'auto'}
# --------------------
# LightGBMLarge
# 0.3470910109461014
# {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5}
# --------------------
# WeightedEnsemble_L2
# 0.3483617816044785
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------

# %%
y_predictor.info()['model_info'].keys()
# Out:
# dict_keys(['KNeighborsUnif', 'KNeighborsDist', 'LightGBMXT', 'LightGBM', 'RandomForestMSE', 'CatBoost', 'ExtraTreesMSE', 'NeuralNetFastAI', 'XGBoost', 'NeuralNetTorch', 'LightGBMLarge', 'WeightedEnsemble_L2'])

# %%
y_predictor = None
y_train = None
y_test = None

# %% [markdown]
# ### Young Bayes Search Hyperparameter (Test 3 times 1:9 CV)

# %%
yy = Df_young['Cantril_ladder']

# %%
Xy = Df_young.drop(columns=['Cantril_ladder'])

# %%
param_space = {
    'n_estimators': Integer(100, 5000),
    'learning_rate': Real(0.001, 0.1, prior='log-uniform'),
    'max_depth': Integer(3, 16),
    'subsample': Real(0.5, 1.0),
    'min_child_weight': Real(0.001, 10, prior='log-uniform'),
    'max_delta_step': Real(0.001, 10, prior='log-uniform'),
    'reg_lambda': Real(0.001, 10, prior='log-uniform'),
    'reg_alpha': Real(0.001, 10, prior='log-uniform'),
    'gamma': Real(0.001, 10, prior='log-uniform')
}

# %%
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror',  device = 'cuda', tree_method='hist', random_state=42, enable_categorical=True)

# %%
class RandomRunNFoldsKFold(KFold):
    def __init__(self, n_splits=10, random_state=None, run_splits=3, **kwargs):
        super().__init__(n_splits=n_splits, shuffle=True, random_state=random_state, **kwargs)
        self.random_state = random_state
        self.actual_splits = run_splits  # Number of actual splits to use

    def split(self, X, y=None, groups=None):
        folds = list(super().split(X, y, groups))
        if self.random_state is not None:
            random.seed(self.random_state)
        selected_folds = random.sample(folds, self.actual_splits)
        for train_index, test_index in selected_folds:
            yield train_index, test_index

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.actual_splits

# %%
rkfcv = RandomRunNFoldsKFold(n_splits=10, run_splits=3, random_state=42)

# %%
bayes_search = BayesSearchCV(
    estimator=xgb_reg,
    search_spaces=param_space,
    n_iter=20,
    scoring='r2',
    cv=rkfcv,
    n_jobs = 1,
    n_points = 1,
    verbose=2,
    random_state=42,
    return_train_score = True
)

# %%
bayes_search.fit(Xy, yy)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# /home/linux/anaconda3/envs/automl/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [20:58:27] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  32.6s
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  30.8s
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  30.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   5.8s
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   6.0s
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   6.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  31.9s
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  33.9s
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  32.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  37.4s
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  37.4s
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  38.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 4.0min
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 4.1min
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 4.1min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  19.0s
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  18.8s
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  19.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 3.7min
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 3.8min
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 3.8min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  54.8s
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  54.1s
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  55.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  21.2s
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  21.7s
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  21.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  17.8s
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  18.3s
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  18.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.001, n_estimators=4020, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  31.9s
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.001, n_estimators=4020, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  30.2s
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.001, n_estimators=4020, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  31.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.03134107165556239, learning_rate=0.049610199600032774, max_delta_step=0.27948964152228817, max_depth=13, min_child_weight=0.004995987173161049, n_estimators=1633, reg_alpha=0.5776062033367358, reg_lambda=0.001284492994547522, subsample=0.725945941967873; total time= 5.6min
# [CV] END gamma=0.03134107165556239, learning_rate=0.049610199600032774, max_delta_step=0.27948964152228817, max_depth=13, min_child_weight=0.004995987173161049, n_estimators=1633, reg_alpha=0.5776062033367358, reg_lambda=0.001284492994547522, subsample=0.725945941967873; total time= 5.6min
# [CV] END gamma=0.03134107165556239, learning_rate=0.049610199600032774, max_delta_step=0.27948964152228817, max_depth=13, min_child_weight=0.004995987173161049, n_estimators=1633, reg_alpha=0.5776062033367358, reg_lambda=0.001284492994547522, subsample=0.725945941967873; total time= 5.5min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=10.0, learning_rate=0.02037474388122372, max_delta_step=10.0, max_depth=3, min_child_weight=10.0, n_estimators=3393, reg_alpha=1.7474704401723336, reg_lambda=0.09239744889348436, subsample=0.9187211828155852; total time=  27.5s
# [CV] END gamma=10.0, learning_rate=0.02037474388122372, max_delta_step=10.0, max_depth=3, min_child_weight=10.0, n_estimators=3393, reg_alpha=1.7474704401723336, reg_lambda=0.09239744889348436, subsample=0.9187211828155852; total time=  27.4s
# [CV] END gamma=10.0, learning_rate=0.02037474388122372, max_delta_step=10.0, max_depth=3, min_child_weight=10.0, n_estimators=3393, reg_alpha=1.7474704401723336, reg_lambda=0.09239744889348436, subsample=0.9187211828155852; total time=  26.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.030012073684372587, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.007952910603033079, n_estimators=100, reg_alpha=0.08888821396108419, reg_lambda=0.001, subsample=0.6719664648843953; total time=   1.7s
# [CV] END gamma=0.030012073684372587, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.007952910603033079, n_estimators=100, reg_alpha=0.08888821396108419, reg_lambda=0.001, subsample=0.6719664648843953; total time=   1.6s
# [CV] END gamma=0.030012073684372587, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.007952910603033079, n_estimators=100, reg_alpha=0.08888821396108419, reg_lambda=0.001, subsample=0.6719664648843953; total time=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.4514366631300794, learning_rate=0.015358273196920586, max_delta_step=0.30912594435697016, max_depth=4, min_child_weight=0.1813711496862004, n_estimators=2447, reg_alpha=0.0659482959056227, reg_lambda=0.41486465489736596, subsample=0.9034814971129799; total time=  22.9s
# [CV] END gamma=0.4514366631300794, learning_rate=0.015358273196920586, max_delta_step=0.30912594435697016, max_depth=4, min_child_weight=0.1813711496862004, n_estimators=2447, reg_alpha=0.0659482959056227, reg_lambda=0.41486465489736596, subsample=0.9034814971129799; total time=  22.3s
# [CV] END gamma=0.4514366631300794, learning_rate=0.015358273196920586, max_delta_step=0.30912594435697016, max_depth=4, min_child_weight=0.1813711496862004, n_estimators=2447, reg_alpha=0.0659482959056227, reg_lambda=0.41486465489736596, subsample=0.9034814971129799; total time=  22.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=3.1020418250537127, learning_rate=0.0033984819900590908, max_delta_step=0.0348290433041593, max_depth=5, min_child_weight=0.013657355717966387, n_estimators=5000, reg_alpha=0.0047882641209689575, reg_lambda=0.001, subsample=0.8737788889961615; total time=  48.5s
# [CV] END gamma=3.1020418250537127, learning_rate=0.0033984819900590908, max_delta_step=0.0348290433041593, max_depth=5, min_child_weight=0.013657355717966387, n_estimators=5000, reg_alpha=0.0047882641209689575, reg_lambda=0.001, subsample=0.8737788889961615; total time=  48.4s
# [CV] END gamma=3.1020418250537127, learning_rate=0.0033984819900590908, max_delta_step=0.0348290433041593, max_depth=5, min_child_weight=0.013657355717966387, n_estimators=5000, reg_alpha=0.0047882641209689575, reg_lambda=0.001, subsample=0.8737788889961615; total time=  48.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.2258070048038772, learning_rate=0.09999999999999999, max_delta_step=0.3164126521361699, max_depth=9, min_child_weight=0.0015169086098357101, n_estimators=4717, reg_alpha=10.0, reg_lambda=0.0014696396259938345, subsample=0.673994712628946; total time= 2.1min
# [CV] END gamma=1.2258070048038772, learning_rate=0.09999999999999999, max_delta_step=0.3164126521361699, max_depth=9, min_child_weight=0.0015169086098357101, n_estimators=4717, reg_alpha=10.0, reg_lambda=0.0014696396259938345, subsample=0.673994712628946; total time= 2.1min
# [CV] END gamma=1.2258070048038772, learning_rate=0.09999999999999999, max_delta_step=0.3164126521361699, max_depth=9, min_child_weight=0.0015169086098357101, n_estimators=4717, reg_alpha=10.0, reg_lambda=0.0014696396259938345, subsample=0.673994712628946; total time= 2.2min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0010936367602707002, learning_rate=0.026533318913007118, max_delta_step=0.14780378625499485, max_depth=12, min_child_weight=0.49282011867662157, n_estimators=211, reg_alpha=10.0, reg_lambda=0.002555475466485115, subsample=0.8833537583422582; total time=  10.4s
# [CV] END gamma=0.0010936367602707002, learning_rate=0.026533318913007118, max_delta_step=0.14780378625499485, max_depth=12, min_child_weight=0.49282011867662157, n_estimators=211, reg_alpha=10.0, reg_lambda=0.002555475466485115, subsample=0.8833537583422582; total time=   9.9s
# [CV] END gamma=0.0010936367602707002, learning_rate=0.026533318913007118, max_delta_step=0.14780378625499485, max_depth=12, min_child_weight=0.49282011867662157, n_estimators=211, reg_alpha=10.0, reg_lambda=0.002555475466485115, subsample=0.8833537583422582; total time=  10.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.2421006665697536, learning_rate=0.019533907378440053, max_delta_step=0.17400026352645911, max_depth=13, min_child_weight=3.0493502853060908, n_estimators=4104, reg_alpha=0.08761268413347378, reg_lambda=0.1485898921169023, subsample=0.5941717281584009; total time=11.4min
# [CV] END gamma=0.2421006665697536, learning_rate=0.019533907378440053, max_delta_step=0.17400026352645911, max_depth=13, min_child_weight=3.0493502853060908, n_estimators=4104, reg_alpha=0.08761268413347378, reg_lambda=0.1485898921169023, subsample=0.5941717281584009; total time=11.4min
# [CV] END gamma=0.2421006665697536, learning_rate=0.019533907378440053, max_delta_step=0.17400026352645911, max_depth=13, min_child_weight=3.0493502853060908, n_estimators=4104, reg_alpha=0.08761268413347378, reg_lambda=0.1485898921169023, subsample=0.5941717281584009; total time=11.5min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.009972447918644768, learning_rate=0.09303913842892136, max_delta_step=9.090027688508851, max_depth=15, min_child_weight=0.7146939023185503, n_estimators=5000, reg_alpha=0.0031570684640825643, reg_lambda=0.0833329940599852, subsample=0.5416437347745308; total time= 8.4min
# [CV] END gamma=0.009972447918644768, learning_rate=0.09303913842892136, max_delta_step=9.090027688508851, max_depth=15, min_child_weight=0.7146939023185503, n_estimators=5000, reg_alpha=0.0031570684640825643, reg_lambda=0.0833329940599852, subsample=0.5416437347745308; total time= 8.3min
# [CV] END gamma=0.009972447918644768, learning_rate=0.09303913842892136, max_delta_step=9.090027688508851, max_depth=15, min_child_weight=0.7146939023185503, n_estimators=5000, reg_alpha=0.0031570684640825643, reg_lambda=0.0833329940599852, subsample=0.5416437347745308; total time= 8.3min
# BayesSearchCV(cv=RandomRunNFoldsKFold(n_splits=10, random_state=42, run_splits=None),
#               estimator=XGBRegressor(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device='cuda',
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, impo...
#                              'min_child_weight': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'n_estimators': Integer(low=100, high=5000, prior='uniform', transform='normalize'),
#                              'reg_alpha': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'reg_lambda': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')},
#               verbose=2)

# %%
CV_result = bayes_search.cv_results_

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_gamma  \
# 8       21.459076      0.223054         0.098571        0.001349    6.636085
# 18     685.561200      2.023588         1.387342        0.141341    0.242101
# 0       31.113476      0.874491         0.162181        0.066385    0.043693
# 9       18.084488      0.276208         0.096471        0.001598    0.001034
# 4      244.502706      1.556659         0.445763        0.005727    1.578388
# 10      31.134863      0.780979         0.133191        0.014681        10.0
# 6      226.110818      3.882657         0.316600        0.003008     0.29398
# 12      27.053499      0.377467         0.124640        0.005364        10.0
# 11     332.954356      1.054010         0.465451        0.020862    0.031341
# 14      22.282337      0.384618         0.131388        0.017242    0.451437
#
#    param_learning_rate param_max_delta_step param_max_depth  \
# 8             0.025191             3.066251               8
# 18            0.019534                0.174              13
# 0              0.02854             5.388551               7
# 9             0.043218              0.92285               6
# 4             0.007517             0.127785              12
# 10                 0.1                 10.0               3
# 6             0.035541             0.027296              14
# 12            0.020375                 10.0               3
# 11             0.04961              0.27949              13
# 14            0.015358             0.309126               4
#
#    param_min_child_weight param_n_estimators  ... split2_test_score  \
# 8                0.033439               1136  ...          0.353873
# 18                3.04935               4104  ...          0.353463
# 0                0.479283               2129  ...          0.352348
# 9                0.206375               1446  ...          0.351273
# 4                4.124851               3613  ...          0.349255
# 10                  0.001               4020  ...          0.341419
# 6                0.234681               3014  ...          0.340237
# 12                   10.0               3393  ...          0.339416
# 11               0.004996               1633  ...          0.339392
# 14               0.181371               2447  ...          0.338672
#
#    mean_test_score std_test_score rank_test_score  split0_train_score  \
# 8         0.352299       0.003107               1            0.427777
# 18        0.351308       0.003416               2            0.821163
# 0         0.350655       0.003205               3            0.424155
# 9         0.349657       0.003159               4            0.394655
# 4         0.347882       0.002695               5            0.435151
# 10        0.340607       0.002872               6            0.352615
# 6         0.338720       0.002487               7            0.391259
# 12        0.338604       0.002779               8            0.347772
# 11        0.337729       0.002541               9            0.941575
# 14        0.337675       0.002917              10            0.348930
#
#     split1_train_score  split2_train_score  mean_train_score  std_train_score  \
# 8             0.427520            0.427362          0.427553         0.000171
# 18            0.820584            0.820593          0.820780         0.000271
# 0             0.423304            0.423278          0.423579         0.000408
# 9             0.394050            0.394083          0.394263         0.000278
# 4             0.434810            0.434683          0.434881         0.000198
# 10            0.351648            0.351893          0.352052         0.000411
# 6             0.390446            0.390839          0.390848         0.000332
# 12            0.347076            0.347256          0.347368         0.000295
# 11            0.941276            0.940728          0.941193         0.000351
# 14            0.348307            0.348438          0.348558         0.000268
#
#     rank_train_score
# 8                  6
# 18                 4
# 0                  7
# 9                  9
# 4                  5
# 10                11
# 6                 10
# 12                13
# 11                 2
# 14                12
#
# [10 rows x 26 columns]

# %%
dump(bayes_search, 'Results/BayesSearchAgeYoung20iter.joblib')
# Out:
# ['Results/BayesSearchAgeYoung20iter.joblib']

# %% [markdown]
# ### Middle Model

# %%
label = 'Cantril_ladder'

# %%
m_predictor = TabularPredictor(label=label, eval_metric='r2', problem_type = 'regression').fit(m_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240622_140326"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.9.19
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          10
# Memory Avail:       108.41 GB / 125.66 GB (86.3%)
# Disk Space Avail:   189.10 GB / 1863.00 GB (10.2%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (597215 samples, 302.2 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240622_140326"
# Train Data Rows:    597215
# Train Data Columns: 62
# Label Column:       Cantril_ladder
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    111290.12 MB
# 	Train Data (Original)  Memory Usage: 279.09 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 53 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) :  1 | ['COUNTRY_ISO3']
# 		('float', [])    : 60 | ['INCOME_2', 'Health_disable', 'Relative_have', 'Living_standard_change', 'Enough_food', ...]
# 		('int', [])      :  1 | ['wave']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  :  1 | ['COUNTRY_ISO3']
# 		('float', [])     :  7 | ['INCOME_2', 'Living_standard_change', 'Economic_change', 'Marital_status', 'Employment', ...]
# 		('int', [])       :  1 | ['wave']
# 		('int', ['bool']) : 53 | ['Health_disable', 'Relative_have', 'Enough_food', 'Enough_shelter', 'Well_rested', ...]
# 	1.3s = Fit runtime
# 	62 features in original data used to generate 62 features in processed data.
# 	Train Data (Processed) Memory Usage: 67.78 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.39s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 591242, Val Rows: 5973
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.151	 = Validation score   (r2)
# 	0.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.1106	 = Validation score   (r2)
# 	0.78s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's l2: 3.67925	valid_set's r2: 0.387841
# 	0.3889	 = Validation score   (r2)
# 	32.63s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's l2: 3.62661	valid_set's r2: 0.396599
# [2000]	valid_set's l2: 3.61762	valid_set's r2: 0.398095
# 	0.3983	 = Validation score   (r2)
# 	46.6s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	0.3479	 = Validation score   (r2)
# 	328.9s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.3949	 = Validation score   (r2)
# 	553.62s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	0.3345	 = Validation score   (r2)
# 	291.19s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.3869	 = Validation score   (r2)
# 	234.77s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.3833	 = Validation score   (r2)
# 	45.74s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.3584	 = Validation score   (r2)
# 	266.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's l2: 3.63698	valid_set's r2: 0.394874
# [2000]	valid_set's l2: 3.62002	valid_set's r2: 0.397695
# [3000]	valid_set's l2: 3.61329	valid_set's r2: 0.398815
# [4000]	valid_set's l2: 3.61009	valid_set's r2: 0.399347
# [5000]	valid_set's l2: 3.6186	valid_set's r2: 0.397931
# 	0.3994	 = Validation score   (r2)
# 	100.77s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBMLarge': 0.471, 'CatBoost': 0.235, 'LightGBM': 0.176, 'NeuralNetFastAI': 0.118}
# 	0.4025	 = Validation score   (r2)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1915.93s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 12964.4 rows/s (5973 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240622_140326")

# %%
m_predictor.evaluate(m_test, silent=True)
# Out:
# {'r2': 0.4065648968667013,
#  'root_mean_squared_error': -1.8498671918083323,
#  'mean_squared_error': -3.4220086273288453,
#  'mean_absolute_error': -1.3907243476647781,
#  'pearsonr': 0.6376429378412016,
#  'median_absolute_error': -1.0624613761901855}

# %%
m_predictor.leaderboard(m_test)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0   WeightedEnsemble_L2    0.406565   0.402497          r2        6.335968
# 1         LightGBMLarge    0.402963   0.399424          r2        4.163403
# 2              LightGBM    0.402133   0.398296          r2        1.501353
# 3              CatBoost    0.399752   0.394906          r2        0.261763
# 4            LightGBMXT    0.396888   0.388896          r2        1.107345
# 5               XGBoost    0.392420   0.383299          r2        1.173206
# 6       NeuralNetFastAI    0.389804   0.386880          r2        0.399417
# 7        NeuralNetTorch    0.370763   0.358375          r2        0.165226
# 8       RandomForestMSE    0.353944   0.347919          r2        3.860600
# 9         ExtraTreesMSE    0.340644   0.334484          r2        3.640697
# 10       KNeighborsUnif    0.171147   0.151049          r2        0.658527
# 11       KNeighborsDist    0.133235   0.110629          r2        0.754881
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.460723  935.827766                 0.010032
# 1        0.285875  100.771887                 4.163403
# 2        0.122820   46.601321                 1.501353
# 3        0.015495  553.617184                 0.261763
# 4        0.090605   32.634315                 1.107345
# 5        0.094652   45.739672                 1.173206
# 6        0.036058  234.771234                 0.399417
# 7        0.014527  266.480672                 0.165226
# 8        0.102350  328.904921                 3.860600
# 9        0.101482  291.189616                 3.640697
# 10       0.036607    0.778093                 0.658527
# 11       0.030963    0.776475                 0.754881
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000476           0.066140            2       True
# 1                 0.285875         100.771887            1       True
# 2                 0.122820          46.601321            1       True
# 3                 0.015495         553.617184            1       True
# 4                 0.090605          32.634315            1       True
# 5                 0.094652          45.739672            1       True
# 6                 0.036058         234.771234            1       True
# 7                 0.014527         266.480672            1       True
# 8                 0.102350         328.904921            1       True
# 9                 0.101482         291.189616            1       True
# 10                0.036607           0.778093            1       True
# 11                0.030963           0.776475            1       True
#
#     fit_order
# 0          12
# 1          11
# 2           4
# 3           6
# 4           3
# 5           9
# 6           8
# 7          10
# 8           5
# 9           7
# 10          1
# 11          2

# %%
for key in m_predictor.info()['model_info'].keys():
    print(m_predictor.info()['model_info'][key]['name'])
    print(m_predictor.info()['model_info'][key]['val_score'])
    print(m_predictor.info()['model_info'][key]['hyperparameters'])
    print("--------------------")
# Out:
# KNeighborsUnif
# 0.15104854404497292
# {'weights': 'uniform'}
# --------------------
# KNeighborsDist
# 0.11062859928441104
# {'weights': 'distance'}
# --------------------
# LightGBMXT
# 0.3888959572992885
# {'learning_rate': 0.05, 'extra_trees': True}
# --------------------
# LightGBM
# 0.398296386013673
# {'learning_rate': 0.05}
# --------------------
# RandomForestMSE
# 0.3479190356052031
# {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# --------------------
# CatBoost
# 0.39490625144960345
# {'iterations': 10000, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'R2'}
# --------------------
# ExtraTreesMSE
# 0.3344837468473997
# {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# --------------------
# NeuralNetFastAI
# 0.38687966797076356
# {'layers': None, 'emb_drop': 0.1, 'ps': 0.1, 'bs': 'auto', 'lr': 0.01, 'epochs': 'auto', 'early.stopping.min_delta': 0.0001, 'early.stopping.patience': 20, 'smoothing': 0.0}
# --------------------
# XGBoost
# 0.3832992766027443
# {'n_estimators': 10000, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'reg:squarederror', 'booster': 'gbtree'}
# --------------------
# NeuralNetTorch
# 0.35837473163048683
# {'num_epochs': 500, 'epochs_wo_improve': 20, 'activation': 'relu', 'embedding_size_factor': 1.0, 'embed_exponent': 0.56, 'max_embedding_dim': 100, 'y_range': None, 'y_range_extend': 0.05, 'dropout_prob': 0.1, 'optimizer': 'adam', 'learning_rate': 0.0003, 'weight_decay': 1e-06, 'proc.embed_min_categories': 4, 'proc.impute_strategy': 'median', 'proc.max_category_levels': 100, 'proc.skew_threshold': 0.99, 'use_ngram_features': False, 'num_layers': 4, 'hidden_size': 128, 'max_batch_size': 512, 'use_batchnorm': False, 'loss_function': 'auto'}
# --------------------
# LightGBMLarge
# 0.39942375986136525
# {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5}
# --------------------
# WeightedEnsemble_L2
# 0.4024973606721475
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------

# %%
m_predictor.info()['model_info'].keys()
# Out:
# dict_keys(['KNeighborsUnif', 'KNeighborsDist', 'LightGBMXT', 'LightGBM', 'RandomForestMSE', 'CatBoost', 'ExtraTreesMSE', 'NeuralNetFastAI', 'XGBoost', 'NeuralNetTorch', 'LightGBMLarge', 'WeightedEnsemble_L2'])

# %%
m_predictor = None
m_train = None
m_test = None

# %% [markdown]
# ### Middle Bayes Search Hyperparameter (Test 3 times 1:9 CV)

# %%
ym = Df_middle['Cantril_ladder']

# %%
Xm = Df_middle.drop(columns=['Cantril_ladder'])

# %%
param_space = {
    'n_estimators': Integer(100, 5000),
    'learning_rate': Real(0.001, 0.1, prior='log-uniform'),
    'max_depth': Integer(3, 16),
    'subsample': Real(0.5, 1.0),
    'min_child_weight': Real(0.001, 10, prior='log-uniform'),
    'max_delta_step': Real(0.001, 10, prior='log-uniform'),
    'reg_lambda': Real(0.001, 10, prior='log-uniform'),
    'reg_alpha': Real(0.001, 10, prior='log-uniform'),
    'gamma': Real(0.001, 10, prior='log-uniform')
}

# %%
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror',  device = 'cuda', tree_method='hist', random_state=42, enable_categorical=True)

# %%
class RandomRunNFoldsKFold(KFold):
    def __init__(self, n_splits=10, random_state=None, run_splits=3, **kwargs):
        super().__init__(n_splits=n_splits, shuffle=True, random_state=random_state, **kwargs)
        self.random_state = random_state
        self.actual_splits = run_splits  # Number of actual splits to use

    def split(self, X, y=None, groups=None):
        folds = list(super().split(X, y, groups))
        if self.random_state is not None:
            random.seed(self.random_state)
        selected_folds = random.sample(folds, self.actual_splits)
        for train_index, test_index in selected_folds:
            yield train_index, test_index

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.actual_splits

# %%
rkfcv = RandomRunNFoldsKFold(n_splits=10, run_splits=3, random_state=42)

# %%
bayes_search = BayesSearchCV(
    estimator=xgb_reg,
    search_spaces=param_space,
    n_iter=20,
    scoring='r2',
    cv=rkfcv,
    n_jobs = 1,
    n_points = 1,
    verbose=2,
    random_state=42,
    return_train_score = True
)

# %%
bayes_search.fit(Xm, ym)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  25.3s
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  24.5s
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  24.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   5.2s
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   5.6s
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   5.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  31.0s
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  29.0s
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  27.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  27.7s
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  28.5s
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  27.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 3.1min
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 3.1min
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 3.2min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  15.2s
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  16.3s
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  16.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 2.5min
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 2.5min
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 2.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  41.1s
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  40.9s
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  42.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  18.6s
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  18.0s
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  18.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  13.7s
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  15.0s
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  14.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.001, n_estimators=3793, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  25.6s
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.001, n_estimators=3793, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  24.9s
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=3, min_child_weight=0.001, n_estimators=3793, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  23.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0744790525120674, learning_rate=0.05116611552891962, max_delta_step=0.2575941597803566, max_depth=9, min_child_weight=0.0050748288828807685, n_estimators=1266, reg_alpha=0.5587445048676529, reg_lambda=0.007682088312308694, subsample=0.8292764306206226; total time=  29.9s
# [CV] END gamma=0.0744790525120674, learning_rate=0.05116611552891962, max_delta_step=0.2575941597803566, max_depth=9, min_child_weight=0.0050748288828807685, n_estimators=1266, reg_alpha=0.5587445048676529, reg_lambda=0.007682088312308694, subsample=0.8292764306206226; total time=  29.4s
# [CV] END gamma=0.0744790525120674, learning_rate=0.05116611552891962, max_delta_step=0.2575941597803566, max_depth=9, min_child_weight=0.0050748288828807685, n_estimators=1266, reg_alpha=0.5587445048676529, reg_lambda=0.007682088312308694, subsample=0.8292764306206226; total time=  29.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=0.3213896768895557, max_depth=14, min_child_weight=0.001, n_estimators=2035, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  39.4s
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=0.3213896768895557, max_depth=14, min_child_weight=0.001, n_estimators=2035, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  40.1s
# [CV] END gamma=10.0, learning_rate=0.09999999999999999, max_delta_step=0.3213896768895557, max_depth=14, min_child_weight=0.001, n_estimators=2035, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  39.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=4.7480826915594925, learning_rate=0.007415441669073655, max_delta_step=0.23722438797433448, max_depth=10, min_child_weight=0.0020068861134277293, n_estimators=2286, reg_alpha=0.022696626833925374, reg_lambda=0.0011123837302686364, subsample=0.7258538337161077; total time= 1.1min
# [CV] END gamma=4.7480826915594925, learning_rate=0.007415441669073655, max_delta_step=0.23722438797433448, max_depth=10, min_child_weight=0.0020068861134277293, n_estimators=2286, reg_alpha=0.022696626833925374, reg_lambda=0.0011123837302686364, subsample=0.7258538337161077; total time= 1.1min
# [CV] END gamma=4.7480826915594925, learning_rate=0.007415441669073655, max_delta_step=0.23722438797433448, max_depth=10, min_child_weight=0.0020068861134277293, n_estimators=2286, reg_alpha=0.022696626833925374, reg_lambda=0.0011123837302686364, subsample=0.7258538337161077; total time= 1.1min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.001, learning_rate=0.001, max_delta_step=1.8501897781909975, max_depth=3, min_child_weight=0.2838314822065428, n_estimators=4088, reg_alpha=0.001, reg_lambda=0.052175260988613935, subsample=1.0; total time=  28.1s
# [CV] END gamma=0.001, learning_rate=0.001, max_delta_step=1.8501897781909975, max_depth=3, min_child_weight=0.2838314822065428, n_estimators=4088, reg_alpha=0.001, reg_lambda=0.052175260988613935, subsample=1.0; total time=  25.8s
# [CV] END gamma=0.001, learning_rate=0.001, max_delta_step=1.8501897781909975, max_depth=3, min_child_weight=0.2838314822065428, n_estimators=4088, reg_alpha=0.001, reg_lambda=0.052175260988613935, subsample=1.0; total time=  25.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.07027067818189624, learning_rate=0.0010530307859249366, max_delta_step=0.02194851778782824, max_depth=3, min_child_weight=6.355131973958979, n_estimators=4321, reg_alpha=0.001, reg_lambda=0.001, subsample=1.0; total time=  30.0s
# [CV] END gamma=0.07027067818189624, learning_rate=0.0010530307859249366, max_delta_step=0.02194851778782824, max_depth=3, min_child_weight=6.355131973958979, n_estimators=4321, reg_alpha=0.001, reg_lambda=0.001, subsample=1.0; total time=  30.5s
# [CV] END gamma=0.07027067818189624, learning_rate=0.0010530307859249366, max_delta_step=0.02194851778782824, max_depth=3, min_child_weight=6.355131973958979, n_estimators=4321, reg_alpha=0.001, reg_lambda=0.001, subsample=1.0; total time=  29.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.05965055817863728, learning_rate=0.016150250040658724, max_delta_step=0.10042448556024319, max_depth=13, min_child_weight=1.7624628686422215, n_estimators=3304, reg_alpha=10.0, reg_lambda=0.002893997263318717, subsample=0.8956214250879957; total time= 4.3min
# [CV] END gamma=0.05965055817863728, learning_rate=0.016150250040658724, max_delta_step=0.10042448556024319, max_depth=13, min_child_weight=1.7624628686422215, n_estimators=3304, reg_alpha=10.0, reg_lambda=0.002893997263318717, subsample=0.8956214250879957; total time= 4.4min
# [CV] END gamma=0.05965055817863728, learning_rate=0.016150250040658724, max_delta_step=0.10042448556024319, max_depth=13, min_child_weight=1.7624628686422215, n_estimators=3304, reg_alpha=10.0, reg_lambda=0.002893997263318717, subsample=0.8956214250879957; total time= 4.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.001, learning_rate=0.015208570196975517, max_delta_step=0.18059084367532777, max_depth=11, min_child_weight=2.1162606529950048, n_estimators=3643, reg_alpha=0.07679130133220857, reg_lambda=10.0, subsample=0.5; total time= 3.5min
# [CV] END gamma=0.001, learning_rate=0.015208570196975517, max_delta_step=0.18059084367532777, max_depth=11, min_child_weight=2.1162606529950048, n_estimators=3643, reg_alpha=0.07679130133220857, reg_lambda=10.0, subsample=0.5; total time= 3.5min
# [CV] END gamma=0.001, learning_rate=0.015208570196975517, max_delta_step=0.18059084367532777, max_depth=11, min_child_weight=2.1162606529950048, n_estimators=3643, reg_alpha=0.07679130133220857, reg_lambda=10.0, subsample=0.5; total time= 3.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.3050941803167826, learning_rate=0.028841175748044456, max_delta_step=0.041116286201354865, max_depth=15, min_child_weight=0.1116207674347007, n_estimators=3456, reg_alpha=2.162296871266628, reg_lambda=0.0049028502553263, subsample=0.8760326180080074; total time= 5.9min
# [CV] END gamma=0.3050941803167826, learning_rate=0.028841175748044456, max_delta_step=0.041116286201354865, max_depth=15, min_child_weight=0.1116207674347007, n_estimators=3456, reg_alpha=2.162296871266628, reg_lambda=0.0049028502553263, subsample=0.8760326180080074; total time= 5.7min
# [CV] END gamma=0.3050941803167826, learning_rate=0.028841175748044456, max_delta_step=0.041116286201354865, max_depth=15, min_child_weight=0.1116207674347007, n_estimators=3456, reg_alpha=2.162296871266628, reg_lambda=0.0049028502553263, subsample=0.8760326180080074; total time= 5.9min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0737907572761416, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=14, min_child_weight=0.0020456535976658293, n_estimators=2267, reg_alpha=0.006323404412177916, reg_lambda=0.06845999897243259, subsample=0.7170549577874701; total time= 2.6min
# [CV] END gamma=0.0737907572761416, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=14, min_child_weight=0.0020456535976658293, n_estimators=2267, reg_alpha=0.006323404412177916, reg_lambda=0.06845999897243259, subsample=0.7170549577874701; total time= 2.5min
# [CV] END gamma=0.0737907572761416, learning_rate=0.09999999999999999, max_delta_step=10.0, max_depth=14, min_child_weight=0.0020456535976658293, n_estimators=2267, reg_alpha=0.006323404412177916, reg_lambda=0.06845999897243259, subsample=0.7170549577874701; total time= 2.5min
# BayesSearchCV(cv=RandomRunNFoldsKFold(n_splits=10, random_state=42, run_splits=None),
#               estimator=XGBRegressor(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device='cuda',
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, impo...
#                              'min_child_weight': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'n_estimators': Integer(low=100, high=5000, prior='uniform', transform='normalize'),
#                              'reg_alpha': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'reg_lambda': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')},
#               verbose=2)

# %%
CV_result = bayes_search.cv_results_

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_gamma  \
# 16     260.862294      1.711591         0.424207        0.010861    0.059651
# 8       18.248148      0.258135         0.072841        0.006537    6.636085
# 18     349.207772      4.081135         0.368426        0.013327    0.305094
# 17     208.355793      2.414097         0.389715        0.003508       0.001
# 0       24.621885      0.406539         0.093761        0.003183    0.043693
# 9       14.480482      0.582251         0.068304        0.001646    0.001034
# 4      187.321864      2.423789         0.273030        0.003884    1.578388
# 13      66.883969      0.849490         0.142458        0.004686    4.748083
# 11      29.329787      0.407253         0.087458        0.004085    0.074479
# 10      24.689996      0.657948         0.116226        0.010542        10.0
#
#    param_learning_rate param_max_delta_step param_max_depth  \
# 16             0.01615             0.100424              13
# 8             0.025191             3.066251               8
# 18            0.028841             0.041116              15
# 17            0.015209             0.180591              11
# 0              0.02854             5.388551               7
# 9             0.043218              0.92285               6
# 4             0.007517             0.127785              12
# 13            0.007415             0.237224              10
# 11            0.051166             0.257594               9
# 10                 0.1                 10.0               3
#
#    param_min_child_weight param_n_estimators  ... split2_test_score  \
# 16               1.762463               3304  ...          0.409534
# 8                0.033439               1136  ...          0.408097
# 18               0.111621               3456  ...          0.407433
# 17               2.116261               3643  ...          0.407909
# 0                0.479283               2129  ...          0.406219
# 9                0.206375               1446  ...          0.405235
# 4                4.124851               3613  ...          0.403955
# 13               0.002007               2286  ...          0.403889
# 11               0.005075               1266  ...          0.402534
# 10                  0.001               3793  ...          0.400948
#
#    mean_test_score std_test_score rank_test_score  split0_train_score  \
# 16        0.409484       0.002884               1            0.603081
# 8         0.408494       0.002911               2            0.510752
# 18        0.407721       0.002816               3            0.539866
# 17        0.407206       0.003293               4            0.640808
# 0         0.406247       0.002979               5            0.507362
# 9         0.406215       0.003111               6            0.470383
# 4         0.404077       0.002602               7            0.490351
# 13        0.404003       0.002629               8            0.478312
# 11        0.402282       0.003668               9            0.611567
# 10        0.402227       0.002759              10            0.414497
#
#     split1_train_score  split2_train_score  mean_train_score  std_train_score  \
# 16            0.603507            0.602626          0.603071         0.000360
# 8             0.511241            0.511645          0.511213         0.000365
# 18            0.539876            0.540185          0.539976         0.000148
# 17            0.641861            0.641575          0.641415         0.000445
# 0             0.508281            0.507866          0.507836         0.000376
# 9             0.471190            0.470495          0.470689         0.000357
# 4             0.490948            0.490809          0.490703         0.000255
# 13            0.478928            0.478735          0.478658         0.000257
# 11            0.611505            0.611150          0.611407         0.000184
# 10            0.415115            0.414986          0.414866         0.000266
#
#     rank_train_score
# 16                 5
# 8                  7
# 18                 6
# 17                 2
# 0                  8
# 9                 11
# 4                  9
# 13                10
# 11                 4
# 10                14
#
# [10 rows x 26 columns]

# %%
dump(bayes_search, 'Results/BayesSearchAgeMiddle20iter.joblib')
# Out:
# ['Results/BayesSearchAgeMiddle20iter.joblib']

# %% [markdown]
# ### Old Model

# %%
label = 'Cantril_ladder'

# %%
o_predictor = TabularPredictor(label=label, eval_metric='r2', problem_type = 'regression').fit(o_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240622_161157"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.9.19
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Mar 29 23:14:13 UTC 2024
# CPU Count:          10
# Memory Avail:       106.94 GB / 125.66 GB (85.1%)
# Disk Space Avail:   187.01 GB / 1863.00 GB (10.0%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (194818 samples, 98.59 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240622_161157"
# Train Data Rows:    194818
# Train Data Columns: 62
# Label Column:       Cantril_ladder
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    109593.85 MB
# 	Train Data (Original)  Memory Usage: 91.05 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 53 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) :  1 | ['COUNTRY_ISO3']
# 		('float', [])    : 60 | ['INCOME_2', 'Health_disable', 'Relative_have', 'Living_standard_change', 'Enough_food', ...]
# 		('int', [])      :  1 | ['wave']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  :  1 | ['COUNTRY_ISO3']
# 		('float', [])     :  7 | ['INCOME_2', 'Living_standard_change', 'Economic_change', 'Marital_status', 'Employment', ...]
# 		('int', [])       :  1 | ['wave']
# 		('int', ['bool']) : 53 | ['Health_disable', 'Relative_have', 'Enough_food', 'Enough_shelter', 'Well_rested', ...]
# 	0.5s = Fit runtime
# 	62 features in original data used to generate 62 features in processed data.
# 	Train Data (Processed) Memory Usage: 22.11 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.55s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01283248981100309, Train Rows: 192318, Val Rows: 2500
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.1229	 = Validation score   (r2)
# 	0.16s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.0932	 = Validation score   (r2)
# 	0.17s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.4142	 = Validation score   (r2)
# 	2.58s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.4185	 = Validation score   (r2)
# 	3.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	0.3743	 = Validation score   (r2)
# 	91.91s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.4149	 = Validation score   (r2)
# 	60.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	0.3611	 = Validation score   (r2)
# 	79.75s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 7: early stopping
# 	0.4051	 = Validation score   (r2)
# 	118.43s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.4061	 = Validation score   (r2)
# 	5.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.3858	 = Validation score   (r2)
# 	80.58s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.4145	 = Validation score   (r2)
# 	3.9s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBM': 0.538, 'CatBoost': 0.308, 'LightGBMXT': 0.077, 'NeuralNetFastAI': 0.077}
# 	0.4207	 = Validation score   (r2)
# 	0.06s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 457.2s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 50688.9 rows/s (2500 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240622_161157")

# %%
o_predictor.evaluate(o_test, silent=True)
# Out:
# {'r2': 0.4091811565472627,
#  'root_mean_squared_error': -1.9389696415833295,
#  'mean_squared_error': -3.7596032709817857,
#  'mean_absolute_error': -1.470345265104979,
#  'pearsonr': 0.6396988015205557,
#  'median_absolute_error': -1.1309094429016113}

# %%
o_predictor.leaderboard(o_test)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0   WeightedEnsemble_L2    0.409181   0.420653          r2        0.501896
# 1              LightGBM    0.406333   0.418502          r2        0.084028
# 2              CatBoost    0.405035   0.414920          r2        0.069346
# 3         LightGBMLarge    0.404382   0.414507          r2        0.125850
# 4            LightGBMXT    0.401434   0.414173          r2        0.074586
# 5               XGBoost    0.400381   0.406121          r2        0.131844
# 6       NeuralNetFastAI    0.394414   0.405077          r2        0.267165
# 7        NeuralNetTorch    0.373904   0.385839          r2        0.059115
# 8       RandomForestMSE    0.367585   0.374342          r2        3.270016
# 9         ExtraTreesMSE    0.356211   0.361113          r2        3.054047
# 10       KNeighborsUnif    0.136437   0.122873          r2        0.202646
# 11       KNeighborsDist    0.098162   0.093172          r2        0.220959
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.049320  184.451424                 0.006771
# 1        0.010414    3.341617                 0.084028
# 2        0.006182   60.035336                 0.069346
# 3        0.011309    3.899840                 0.125850
# 4        0.007113    2.581644                 0.074586
# 5        0.014667    5.422534                 0.131844
# 6        0.025193  118.431652                 0.267165
# 7        0.011439   80.581688                 0.059115
# 8        0.113011   91.906038                 3.270016
# 9        0.107785   79.747095                 3.054047
# 10       0.019072    0.155951                 0.202646
# 11       0.018983    0.166186                 0.220959
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000418           0.061175            2       True
# 1                 0.010414           3.341617            1       True
# 2                 0.006182          60.035336            1       True
# 3                 0.011309           3.899840            1       True
# 4                 0.007113           2.581644            1       True
# 5                 0.014667           5.422534            1       True
# 6                 0.025193         118.431652            1       True
# 7                 0.011439          80.581688            1       True
# 8                 0.113011          91.906038            1       True
# 9                 0.107785          79.747095            1       True
# 10                0.019072           0.155951            1       True
# 11                0.018983           0.166186            1       True
#
#     fit_order
# 0          12
# 1           4
# 2           6
# 3          11
# 4           3
# 5           9
# 6           8
# 7          10
# 8           5
# 9           7
# 10          1
# 11          2

# %%
for key in o_predictor.info()['model_info'].keys():
    print(o_predictor.info()['model_info'][key]['name'])
    print(o_predictor.info()['model_info'][key]['val_score'])
    print(o_predictor.info()['model_info'][key]['hyperparameters'])
    print("--------------------")
# Out:
# KNeighborsUnif
# 0.1228731531441769
# {'weights': 'uniform'}
# --------------------
# KNeighborsDist
# 0.09317201281982823
# {'weights': 'distance'}
# --------------------
# LightGBMXT
# 0.4141734629709759
# {'learning_rate': 0.05, 'extra_trees': True}
# --------------------
# LightGBM
# 0.41850232384736175
# {'learning_rate': 0.05}
# --------------------
# RandomForestMSE
# 0.37434198414076314
# {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# --------------------
# CatBoost
# 0.414920284944005
# {'iterations': 10000, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'R2'}
# --------------------
# ExtraTreesMSE
# 0.36111280334931484
# {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# --------------------
# NeuralNetFastAI
# 0.40507733591091477
# {'layers': None, 'emb_drop': 0.1, 'ps': 0.1, 'bs': 'auto', 'lr': 0.01, 'epochs': 'auto', 'early.stopping.min_delta': 0.0001, 'early.stopping.patience': 20, 'smoothing': 0.0}
# --------------------
# XGBoost
# 0.4061211097191687
# {'n_estimators': 10000, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'reg:squarederror', 'booster': 'gbtree'}
# --------------------
# NeuralNetTorch
# 0.3858388966363133
# {'num_epochs': 500, 'epochs_wo_improve': 20, 'activation': 'relu', 'embedding_size_factor': 1.0, 'embed_exponent': 0.56, 'max_embedding_dim': 100, 'y_range': None, 'y_range_extend': 0.05, 'dropout_prob': 0.1, 'optimizer': 'adam', 'learning_rate': 0.0003, 'weight_decay': 1e-06, 'proc.embed_min_categories': 4, 'proc.impute_strategy': 'median', 'proc.max_category_levels': 100, 'proc.skew_threshold': 0.99, 'use_ngram_features': False, 'num_layers': 4, 'hidden_size': 128, 'max_batch_size': 512, 'use_batchnorm': False, 'loss_function': 'auto'}
# --------------------
# LightGBMLarge
# 0.4145073115098159
# {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5}
# --------------------
# WeightedEnsemble_L2
# 0.4206533341649802
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------

# %%
o_predictor.info()['model_info'].keys()
# Out:
# dict_keys(['KNeighborsUnif', 'KNeighborsDist', 'LightGBMXT', 'LightGBM', 'RandomForestMSE', 'CatBoost', 'ExtraTreesMSE', 'NeuralNetFastAI', 'XGBoost', 'NeuralNetTorch', 'LightGBMLarge', 'WeightedEnsemble_L2'])

# %%
o_predictor = None
o_train = None
o_test = None

# %% [markdown]
# ### Old Bayes Search Hyperparameter (Test 3 times 1:9 CV)

# %%
yo = Df_old['Cantril_ladder']

# %%
Xo = Df_old.drop(columns=['Cantril_ladder'])

# %%
param_space = {
    'n_estimators': Integer(100, 5000),
    'learning_rate': Real(0.001, 0.1, prior='log-uniform'),
    'max_depth': Integer(3, 16),
    'subsample': Real(0.5, 1.0),
    'min_child_weight': Real(0.001, 10, prior='log-uniform'),
    'max_delta_step': Real(0.001, 10, prior='log-uniform'),
    'reg_lambda': Real(0.001, 10, prior='log-uniform'),
    'reg_alpha': Real(0.001, 10, prior='log-uniform'),
    'gamma': Real(0.001, 10, prior='log-uniform')
}

# %%
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror',  device = 'cuda', tree_method='hist', random_state=42, enable_categorical=True)

# %%
class RandomRunNFoldsKFold(KFold):
    def __init__(self, n_splits=10, random_state=None, run_splits=3, **kwargs):
        super().__init__(n_splits=n_splits, shuffle=True, random_state=random_state, **kwargs)
        self.random_state = random_state
        self.actual_splits = run_splits  # Number of actual splits to use

    def split(self, X, y=None, groups=None):
        folds = list(super().split(X, y, groups))
        if self.random_state is not None:
            random.seed(self.random_state)
        selected_folds = random.sample(folds, self.actual_splits)
        for train_index, test_index in selected_folds:
            yield train_index, test_index

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.actual_splits

# %%
rkfcv = RandomRunNFoldsKFold(n_splits=10, run_splits=3, random_state=42)

# %%
bayes_search = BayesSearchCV(
    estimator=xgb_reg,
    search_spaces=param_space,
    n_iter=20,
    scoring='r2',
    cv=rkfcv,
    n_jobs = 1,
    n_points = 1,
    verbose=2,
    random_state=42,
    return_train_score = True
)

# %%
bayes_search.fit(Xo, yo)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  19.2s
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  19.2s
# [CV] END gamma=0.04369339947510315, learning_rate=0.02853983686604182, max_delta_step=5.388550972627239, max_depth=7, min_child_weight=0.47928274405969296, n_estimators=2129, reg_alpha=0.025335258486348353, reg_lambda=0.9078559343576645, subsample=0.6522316555182531; total time=  19.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   3.5s
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   3.5s
# [CV] END gamma=2.236420282054271, learning_rate=0.058429282697611454, max_delta_step=0.016354619314682416, max_depth=15, min_child_weight=2.8609591832863424, n_estimators=405, reg_alpha=0.0035746551640890665, reg_lambda=0.025962684183737327, subsample=0.8178645509395852; total time=   3.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  24.0s
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  25.5s
# [CV] END gamma=0.06016307829589929, learning_rate=0.06877728743793542, max_delta_step=0.002626858226437905, max_depth=9, min_child_weight=0.005647038458633676, n_estimators=2323, reg_alpha=0.00418593245501055, reg_lambda=1.0144020667237337, subsample=0.7786702115169006; total time=  24.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  17.0s
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  15.8s
# [CV] END gamma=1.7765766649807682, learning_rate=0.0022066991249460105, max_delta_step=0.24671088435225733, max_depth=13, min_child_weight=0.12365432532396153, n_estimators=568, reg_alpha=1.0548777482285936, reg_lambda=3.094007864244482, subsample=0.9559644307534418; total time=  16.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 1.9min
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 1.9min
# [CV] END gamma=1.5783879853890563, learning_rate=0.007517239253342656, max_delta_step=0.1277853151889843, max_depth=12, min_child_weight=4.124851234284971, n_estimators=3613, reg_alpha=0.04974074547470406, reg_lambda=0.3991502512609639, subsample=0.6765419227639857; total time= 1.9min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  11.2s
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  11.6s
# [CV] END gamma=0.8632012725909878, learning_rate=0.0756379021867824, max_delta_step=0.004512619487621619, max_depth=5, min_child_weight=1.5922561163725886, n_estimators=1926, reg_alpha=0.06856430159759418, reg_lambda=0.1377401781906964, subsample=0.8926419685712479; total time=  12.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 1.4min
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 1.5min
# [CV] END gamma=0.2939797620271688, learning_rate=0.035540927532494104, max_delta_step=0.027295542332669995, max_depth=14, min_child_weight=0.23468141668216005, n_estimators=3014, reg_alpha=0.393649803341925, reg_lambda=0.048789946714619455, subsample=0.866941242634403; total time= 1.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  22.3s
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  22.4s
# [CV] END gamma=0.14914622679778672, learning_rate=0.06918603669668356, max_delta_step=0.09679809588492402, max_depth=14, min_child_weight=0.019780621330832346, n_estimators=351, reg_alpha=0.19191601211845516, reg_lambda=0.0012682484500023282, subsample=0.6928647954923324; total time=  23.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  12.9s
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  13.6s
# [CV] END gamma=6.6360850776123375, learning_rate=0.02519085390684862, max_delta_step=3.0662510776734475, max_depth=8, min_child_weight=0.03343944487838535, n_estimators=1136, reg_alpha=0.001000562456331363, reg_lambda=0.030390787275205566, subsample=0.7971894567956928; total time=  13.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  11.7s
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  11.5s
# [CV] END gamma=0.0010340016434251913, learning_rate=0.04321753967138224, max_delta_step=0.9228497044562662, max_depth=6, min_child_weight=0.20637512290600768, n_estimators=1446, reg_alpha=0.017838454498583053, reg_lambda=0.0040773533275832545, subsample=0.9469190305262598; total time=  11.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=10.0, learning_rate=0.08654286922601485, max_delta_step=10.0, max_depth=6, min_child_weight=0.001, n_estimators=3826, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  29.9s
# [CV] END gamma=10.0, learning_rate=0.08654286922601485, max_delta_step=10.0, max_depth=6, min_child_weight=0.001, n_estimators=3826, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  26.5s
# [CV] END gamma=10.0, learning_rate=0.08654286922601485, max_delta_step=10.0, max_depth=6, min_child_weight=0.001, n_estimators=3826, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  26.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.2045479993021058, learning_rate=0.030685320506680522, max_delta_step=0.3805781770349062, max_depth=13, min_child_weight=0.002361695637610135, n_estimators=540, reg_alpha=6.59041086695112, reg_lambda=0.01642699361057668, subsample=0.5572023993404673; total time=  32.9s
# [CV] END gamma=1.2045479993021058, learning_rate=0.030685320506680522, max_delta_step=0.3805781770349062, max_depth=13, min_child_weight=0.002361695637610135, n_estimators=540, reg_alpha=6.59041086695112, reg_lambda=0.01642699361057668, subsample=0.5572023993404673; total time=  34.6s
# [CV] END gamma=1.2045479993021058, learning_rate=0.030685320506680522, max_delta_step=0.3805781770349062, max_depth=13, min_child_weight=0.002361695637610135, n_estimators=540, reg_alpha=6.59041086695112, reg_lambda=0.01642699361057668, subsample=0.5572023993404673; total time=  34.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.013327391674761595, learning_rate=0.01768235375831889, max_delta_step=0.23097391966538178, max_depth=5, min_child_weight=0.006522508683632291, n_estimators=2963, reg_alpha=0.12763659208697645, reg_lambda=0.012367771810488645, subsample=0.6382542306341656; total time=  19.3s
# [CV] END gamma=0.013327391674761595, learning_rate=0.01768235375831889, max_delta_step=0.23097391966538178, max_depth=5, min_child_weight=0.006522508683632291, n_estimators=2963, reg_alpha=0.12763659208697645, reg_lambda=0.012367771810488645, subsample=0.6382542306341656; total time=  19.9s
# [CV] END gamma=0.013327391674761595, learning_rate=0.01768235375831889, max_delta_step=0.23097391966538178, max_depth=5, min_child_weight=0.006522508683632291, n_estimators=2963, reg_alpha=0.12763659208697645, reg_lambda=0.012367771810488645, subsample=0.6382542306341656; total time=  19.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.017491907689159963, learning_rate=0.052416255288744974, max_delta_step=0.34262488265950003, max_depth=14, min_child_weight=0.09659252917146098, n_estimators=984, reg_alpha=0.9251154503586607, reg_lambda=0.0024880218230035073, subsample=0.8632769743257699; total time= 3.1min
# [CV] END gamma=0.017491907689159963, learning_rate=0.052416255288744974, max_delta_step=0.34262488265950003, max_depth=14, min_child_weight=0.09659252917146098, n_estimators=984, reg_alpha=0.9251154503586607, reg_lambda=0.0024880218230035073, subsample=0.8632769743257699; total time= 3.0min
# [CV] END gamma=0.017491907689159963, learning_rate=0.052416255288744974, max_delta_step=0.34262488265950003, max_depth=14, min_child_weight=0.09659252917146098, n_estimators=984, reg_alpha=0.9251154503586607, reg_lambda=0.0024880218230035073, subsample=0.8632769743257699; total time= 2.9min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.9804413101265342, learning_rate=0.07006269567757534, max_delta_step=10.0, max_depth=16, min_child_weight=0.001, n_estimators=226, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  31.8s
# [CV] END gamma=0.9804413101265342, learning_rate=0.07006269567757534, max_delta_step=10.0, max_depth=16, min_child_weight=0.001, n_estimators=226, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  31.9s
# [CV] END gamma=0.9804413101265342, learning_rate=0.07006269567757534, max_delta_step=10.0, max_depth=16, min_child_weight=0.001, n_estimators=226, reg_alpha=10.0, reg_lambda=0.001, subsample=0.5; total time=  31.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0018037724980486689, learning_rate=0.009201141685784507, max_delta_step=0.7233542594816477, max_depth=10, min_child_weight=1.5068226855452058, n_estimators=2617, reg_alpha=0.005504631601649801, reg_lambda=0.0064937526228321975, subsample=0.7634140139461424; total time= 1.4min
# [CV] END gamma=0.0018037724980486689, learning_rate=0.009201141685784507, max_delta_step=0.7233542594816477, max_depth=10, min_child_weight=1.5068226855452058, n_estimators=2617, reg_alpha=0.005504631601649801, reg_lambda=0.0064937526228321975, subsample=0.7634140139461424; total time= 1.4min
# [CV] END gamma=0.0018037724980486689, learning_rate=0.009201141685784507, max_delta_step=0.7233542594816477, max_depth=10, min_child_weight=1.5068226855452058, n_estimators=2617, reg_alpha=0.005504631601649801, reg_lambda=0.0064937526228321975, subsample=0.7634140139461424; total time= 1.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=0.0597500270916487, learning_rate=0.07882327438602564, max_delta_step=0.017176668099974524, max_depth=10, min_child_weight=0.009662259761208642, n_estimators=2675, reg_alpha=10.0, reg_lambda=0.9764472854118269, subsample=0.6660838266627205; total time=  36.0s
# [CV] END gamma=0.0597500270916487, learning_rate=0.07882327438602564, max_delta_step=0.017176668099974524, max_depth=10, min_child_weight=0.009662259761208642, n_estimators=2675, reg_alpha=10.0, reg_lambda=0.9764472854118269, subsample=0.6660838266627205; total time=  38.2s
# [CV] END gamma=0.0597500270916487, learning_rate=0.07882327438602564, max_delta_step=0.017176668099974524, max_depth=10, min_child_weight=0.009662259761208642, n_estimators=2675, reg_alpha=10.0, reg_lambda=0.9764472854118269, subsample=0.6660838266627205; total time=  36.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=4.274583981386579, learning_rate=0.029095823622004805, max_delta_step=0.03272793838863127, max_depth=14, min_child_weight=0.025073815147984853, n_estimators=3154, reg_alpha=10.0, reg_lambda=0.9836031444795943, subsample=0.5149767180056195; total time=  23.9s
# [CV] END gamma=4.274583981386579, learning_rate=0.029095823622004805, max_delta_step=0.03272793838863127, max_depth=14, min_child_weight=0.025073815147984853, n_estimators=3154, reg_alpha=10.0, reg_lambda=0.9836031444795943, subsample=0.5149767180056195; total time=  25.8s
# [CV] END gamma=4.274583981386579, learning_rate=0.029095823622004805, max_delta_step=0.03272793838863127, max_depth=14, min_child_weight=0.025073815147984853, n_estimators=3154, reg_alpha=10.0, reg_lambda=0.9836031444795943, subsample=0.5149767180056195; total time=  25.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=1.3803328950433693, learning_rate=0.01096351131991069, max_delta_step=0.2068356027519316, max_depth=14, min_child_weight=2.0638468787283735, n_estimators=4920, reg_alpha=0.03441545811481527, reg_lambda=0.09774555121384146, subsample=0.5298287440111218; total time= 6.3min
# [CV] END gamma=1.3803328950433693, learning_rate=0.01096351131991069, max_delta_step=0.2068356027519316, max_depth=14, min_child_weight=2.0638468787283735, n_estimators=4920, reg_alpha=0.03441545811481527, reg_lambda=0.09774555121384146, subsample=0.5298287440111218; total time= 6.3min
# [CV] END gamma=1.3803328950433693, learning_rate=0.01096351131991069, max_delta_step=0.2068356027519316, max_depth=14, min_child_weight=2.0638468787283735, n_estimators=4920, reg_alpha=0.03441545811481527, reg_lambda=0.09774555121384146, subsample=0.5298287440111218; total time= 6.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END gamma=4.86924134517326, learning_rate=0.0045185772567948685, max_delta_step=10.0, max_depth=5, min_child_weight=4.862170525060783, n_estimators=355, reg_alpha=0.001, reg_lambda=0.003073416074532452, subsample=0.902978105009588; total time=   2.0s
# [CV] END gamma=4.86924134517326, learning_rate=0.0045185772567948685, max_delta_step=10.0, max_depth=5, min_child_weight=4.862170525060783, n_estimators=355, reg_alpha=0.001, reg_lambda=0.003073416074532452, subsample=0.902978105009588; total time=   2.4s
# [CV] END gamma=4.86924134517326, learning_rate=0.0045185772567948685, max_delta_step=10.0, max_depth=5, min_child_weight=4.862170525060783, n_estimators=355, reg_alpha=0.001, reg_lambda=0.003073416074532452, subsample=0.902978105009588; total time=   2.3s
# BayesSearchCV(cv=RandomRunNFoldsKFold(n_splits=10, random_state=42, run_splits=None),
#               estimator=XGBRegressor(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device='cuda',
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, impo...
#                              'min_child_weight': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'n_estimators': Integer(low=100, high=5000, prior='uniform', transform='normalize'),
#                              'reg_alpha': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'reg_lambda': Real(low=0.001, high=10, prior='log-uniform', transform='normalize'),
#                              'subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')},
#               verbose=2)

# %%
CV_result = bayes_search.cv_results_

# %%
pd.DataFrame(CV_result).sort_values(by='rank_test_score', ascending=True).head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_gamma  \
# 11      34.022171      0.825355         0.056066        0.001606    1.204548
# 12      19.295416      0.385987         0.102948        0.013590    0.013327
# 4      114.631698      0.919842         0.145908        0.005955    1.578388
# 16      36.734434      0.998943         0.098995        0.016352     0.05975
# 8       13.326068      0.314739         0.047749        0.002803    6.636085
# 15      83.710865      0.464596         0.150129        0.012521    0.001804
# 6       86.718273      1.347586         0.112310        0.004167     0.29398
# 9       11.583722      0.085463         0.049511        0.003244    0.001034
# 17      25.098668      0.913748         0.078970        0.011291    4.274584
# 18     379.988634      0.431316         0.673549        0.086981    1.380333
#
#    param_learning_rate param_max_delta_step param_max_depth  \
# 11            0.030685             0.380578              13
# 12            0.017682             0.230974               5
# 4             0.007517             0.127785              12
# 16            0.078823             0.017177              10
# 8             0.025191             3.066251               8
# 15            0.009201             0.723354              10
# 6             0.035541             0.027296              14
# 9             0.043218              0.92285               6
# 17            0.029096             0.032728              14
# 18            0.010964             0.206836              14
#
#    param_min_child_weight param_n_estimators  ... split2_test_score  \
# 11               0.002362                540  ...          0.407185
# 12               0.006523               2963  ...          0.405702
# 4                4.124851               3613  ...          0.405466
# 16               0.009662               2675  ...          0.402766
# 8                0.033439               1136  ...          0.402558
# 15               1.506823               2617  ...          0.400922
# 6                0.234681               3014  ...          0.398283
# 9                0.206375               1446  ...          0.399324
# 17               0.025074               3154  ...          0.394850
# 18               2.063847               4920  ...          0.393636
#
#    mean_test_score std_test_score rank_test_score  split0_train_score  \
# 11        0.404628       0.002094               1            0.671441
# 12        0.404047       0.001245               2            0.462536
# 4         0.403964       0.001318               3            0.516970
# 16        0.401637       0.000994               4            0.451411
# 8         0.400894       0.001782               5            0.609858
# 15        0.399224       0.001206               6            0.769948
# 6         0.397309       0.000878               7            0.461502
# 9         0.396914       0.001704               8            0.559198
# 17        0.393637       0.001118               9            0.411829
# 18        0.391162       0.001854              10            0.881300
#
#     split1_train_score  split2_train_score  mean_train_score  std_train_score  \
# 11            0.672732            0.672991          0.672388         0.000678
# 12            0.462291            0.462452          0.462426         0.000101
# 4             0.516895            0.516755          0.516873         0.000089
# 16            0.451293            0.451099          0.451268         0.000128
# 8             0.609187            0.609968          0.609671         0.000345
# 15            0.768992            0.770053          0.769664         0.000478
# 6             0.461248            0.460855          0.461201         0.000266
# 9             0.558981            0.558576          0.558919         0.000258
# 17            0.411731            0.411391          0.411650         0.000188
# 18            0.881330            0.881162          0.881264         0.000073
#
#     rank_train_score
# 11                 5
# 12                12
# 4                 10
# 16                14
# 8                  8
# 15                 4
# 6                 13
# 9                  9
# 17                15
# 18                 2
#
# [10 rows x 26 columns]

# %%
dump(bayes_search, 'Results/BayesSearchAgeOld20iter.joblib')
# Out:
# ['Results/BayesSearchAgeOld20iter.joblib']
