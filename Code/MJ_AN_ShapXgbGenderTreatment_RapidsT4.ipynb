# %% [markdown]
# # SHAP Values for XGB To Analyze Treatment Effect between Gender

# %%
# %pwd
# Out:
# '/home/GPU/GallupWellBeingResearch'

# %%
# %cd ..
# Out:
# /home/GPU/GallupWellBeingResearch
# /home/GPU/miniconda3/envs/rapids-24.06/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## Import Package

# %%
import matplotlib.pyplot as plt
from joblib import dump, load
import os 
import pandas as pd
#import shap
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb

# %%
xgb.__version__
# Out:
# '2.0.3'

# %%
from cuml.explainer import KernelExplainer

# %%
import cudf

# %%
import warnings

warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## SHAP

# %% [markdown]
# ### load data and hyperparameter

# %%
hyper_dict = {'gamma': 0.01230893738822448,
 'learning_rate': 0.03929984746983189,
 'max_delta_step': 0.954107364480465,
 'max_depth': 29,
 'min_child_weight': 10.0,
 'n_estimators': 5000,
 'reg_alpha': 2.8833022521389937,
 'reg_lambda': 0.0016481010416658545,
 'subsample': 0.6431757974530777}

# %%
Df_Filename = os.path.join("Data", "GallupWB_Ml64var1911k14waveCounOneHot_v1.parquet")

# %%
Df_countryOneHot = pd.read_parquet(Df_Filename)

# %%
y = Df_countryOneHot['TreatmentEffectFemMal']
X = Df_countryOneHot.drop(columns=['Cantril_ladder', 'MaleReal_y', 'TreatedAsMale', 'FemaleReal_y', 'TreatedAsFemale',
                                   'TreatmentEffectFemMal', 'COUNTRY_ISO3', 'Gender_female'])

# %% [markdown]
# ### Shap Computation

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
Shap_df = []

i = 1
for train_index, test_index in kf.split(Xtot):
    print(f"This is {i} fold")
    X_train, X_test = Xtot.iloc[train_index, :], Xtot.iloc[test_index, :]
    y_train, y_test = ytot.iloc[train_index], ytot.iloc[test_index]
    print(X_test.iloc[:100,:].shape)

    cX_train = cudf.from_pandas(X_train)
    cX_test = cudf.from_pandas(X_test)
    cy_train = cudf.from_pandas(y_train)
    cy_test = cudf.from_pandas(y_test)
    
    # Train the model
    model = xgb.XGBRegressor(objective='reg:squarederror', tree_method='hist', random_state=42, device = 'cuda', **hyper_dict)
    model.fit(cX_train, cy_train)
    
    print('model done')

    colnames = X_test.columns + '_shap'

    background = cudf.from_pandas(X_train.iloc[:100,:])
    cu_explainer = KernelExplainer(model=model.predict,
                                   data=background,
                                   is_gpu_model=True, random_state=42)
    
    interval = 1000
    for row in list(range(0, X_test.shape[0], interval)):
        print(f'here{row}:{row + interval}')
        # %time cu_shap_value_merge = cu_explainer.shap_values(X_test.iloc[row:row + interval,:])
        X_test_shap = pd.DataFrame(cu_shap_value_merge, columns=colnames, index=X_test.index[row:row + interval])
        X_test_merge = pd.concat([y_test.iloc[row:row + interval], X_test.iloc[row:row + interval,:], X_test_shap], axis=1)

        X_test_merge.to_parquet(f'Results/ShapAll/X_test_{row}_{row + interval}.parquet')
        Shap_df.append(X_test_merge)

    dump(Shap_df, "Results/Shap_GenderTreamentDifference.joblib")
    break
# Out:
# This is 1 fold
# (100, 63)
# /home/GPU/miniconda3/envs/rapids-24.06/lib/python3.9/site-packages/xgboost/data.py:849: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# here141000:142000
# CPU times: user 26min 42s, sys: 11.5 s, total: 26min 54s
# Wall time: 10min 15s
# here142000:143000
# CPU times: user 26min 38s, sys: 11.6 s, total: 26min 49s
# Wall time: 10min 14s
# here143000:144000
# CPU times: user 26min 43s, sys: 11.5 s, total: 26min 55s
# Wall time: 10min 17s
# here144000:145000
# CPU times: user 26min 39s, sys: 11.3 s, total: 26min 50s
# Wall time: 10min 16s
# here145000:146000
# CPU times: user 26min 28s, sys: 11.6 s, total: 26min 40s
# Wall time: 10min 15s
# here146000:147000
# CPU times: user 26min 46s, sys: 11.5 s, total: 26min 58s
# Wall time: 10min 16s
# here147000:148000
# CPU times: user 26min 40s, sys: 11.4 s, total: 26min 51s
# Wall time: 10min 16s
# here148000:149000
# CPU times: user 26min 36s, sys: 11.6 s, total: 26min 48s
# Wall time: 10min 16s
# here149000:150000
# CPU times: user 26min 36s, sys: 11.8 s, total: 26min 48s
# Wall time: 10min 14s
# here150000:151000
# CPU times: user 26min 33s, sys: 11.6 s, total: 26min 45s
# Wall time: 10min 14s
# here151000:152000
# CPU times: user 26min 32s, sys: 11.3 s, total: 26min 43s
# Wall time: 10min 14s
# here152000:153000
# CPU times: user 26min 45s, sys: 11.5 s, total: 26min 56s
# Wall time: 10min 16s
# here153000:154000
# CPU times: user 26min 36s, sys: 11.5 s, total: 26min 47s
# Wall time: 10min 15s
# here154000:155000
# CPU times: user 26min 33s, sys: 11.5 s, total: 26min 45s
# Wall time: 10min 15s
# here155000:156000
# CPU times: user 26min 47s, sys: 11.4 s, total: 26min 58s
# Wall time: 10min 16s
# here156000:157000
# CPU times: user 26min 49s, sys: 11.5 s, total: 27min 1s
# Wall time: 10min 17s
# here157000:158000
# CPU times: user 26min 44s, sys: 11.7 s, total: 26min 56s
# Wall time: 10min 16s
# here158000:159000
# CPU times: user 26min 42s, sys: 11.7 s, total: 26min 54s
# Wall time: 10min 16s
# here159000:160000
# CPU times: user 26min 36s, sys: 11.2 s, total: 26min 47s
# Wall time: 10min 14s
# here160000:161000
# CPU times: user 26min 45s, sys: 11.7 s, total: 26min 57s
# Wall time: 10min 16s
# here161000:162000
# CPU times: user 26min 35s, sys: 13.2 s, total: 26min 49s
# Wall time: 10min 18s
# here162000:163000
# CPU times: user 26min 32s, sys: 13.2 s, total: 26min 46s
# Wall time: 10min 18s
# here163000:164000
# CPU times: user 26min 48s, sys: 13.2 s, total: 27min 2s
# Wall time: 10min 18s
# here164000:165000
# CPU times: user 26min 46s, sys: 12.6 s, total: 26min 59s
# Wall time: 10min 16s
# here165000:166000
# CPU times: user 26min 53s, sys: 13.2 s, total: 27min 7s
# Wall time: 10min 19s
# here166000:167000
# CPU times: user 26min 42s, sys: 13.1 s, total: 26min 56s
# Wall time: 10min 17s
# here167000:168000
# CPU times: user 26min 51s, sys: 13.1 s, total: 27min 4s
# Wall time: 10min 17s
# here168000:169000
# CPU times: user 26min 39s, sys: 13.2 s, total: 26min 53s
# Wall time: 10min 17s
# here169000:170000
# CPU times: user 26min 38s, sys: 13 s, total: 26min 51s
# Wall time: 10min 17s
# here170000:171000
# CPU times: user 26min 39s, sys: 12.9 s, total: 26min 51s
# Wall time: 10min 17s
# here171000:172000
# CPU times: user 26min 28s, sys: 13.1 s, total: 26min 41s
# Wall time: 10min 17s
# here172000:173000
# CPU times: user 26min 47s, sys: 13.2 s, total: 27min
# Wall time: 10min 17s
# here173000:174000
# CPU times: user 26min 46s, sys: 13.4 s, total: 26min 59s
# Wall time: 10min 16s
# here174000:175000
# CPU times: user 26min 42s, sys: 13.4 s, total: 26min 55s
# Wall time: 10min 17s
# here175000:176000
# CPU times: user 26min 43s, sys: 13.5 s, total: 26min 56s
# Wall time: 10min 17s
# here176000:177000
# CPU times: user 26min 33s, sys: 13.5 s, total: 26min 46s
# Wall time: 10min 16s
# here177000:178000
# CPU times: user 27min 5s, sys: 13.6 s, total: 27min 19s
# Wall time: 10min 20s
# here178000:179000
# CPU times: user 26min 46s, sys: 13.4 s, total: 26min 59s
# Wall time: 10min 16s
# here179000:180000
# CPU times: user 26min 40s, sys: 13.4 s, total: 26min 53s
# Wall time: 10min 17s
# here180000:181000
# CPU times: user 26min 45s, sys: 13.2 s, total: 26min 58s
# Wall time: 10min 18s
# here181000:182000
# CPU times: user 26min 39s, sys: 13.5 s, total: 26min 52s
# Wall time: 10min 16s
# here182000:183000
# CPU times: user 26min 36s, sys: 13.4 s, total: 26min 49s
# Wall time: 10min 15s
# here183000:184000
# CPU times: user 26min 45s, sys: 13.3 s, total: 26min 58s
# Wall time: 10min 17s
# here184000:185000
# CPU times: user 26min 40s, sys: 13.5 s, total: 26min 53s
# Wall time: 10min 17s
# here185000:186000
# CPU times: user 26min 41s, sys: 13.3 s, total: 26min 54s
# Wall time: 10min 17s
# here186000:187000
# CPU times: user 26min 38s, sys: 13.3 s, total: 26min 51s
# Wall time: 10min 15s
# here187000:188000
# CPU times: user 26min 36s, sys: 13.5 s, total: 26min 49s
# Wall time: 10min 16s
# here188000:189000
# CPU times: user 26min 42s, sys: 13.5 s, total: 26min 56s
# Wall time: 10min 18s
# here189000:190000
# CPU times: user 26min 42s, sys: 13.4 s, total: 26min 55s
# Wall time: 10min 16s
# here190000:191000
# CPU times: user 26min 43s, sys: 13.1 s, total: 26min 56s
# Wall time: 10min 16s
# here191000:192000
# CPU times: user 3min 13s, sys: 1.51 s, total: 3min 14s
# Wall time: 1min 14s

# %%
Concat_Shap = pd.concat(Shap_df, axis=0)

# %%
Concat_Shap.shape
# Out:
# (1911212, 127)

# %%
Concat_Shap.columns
# Out:
# Index(['Cantril_ladder', 'wave', 'INCOME_2', 'Health_disable', 'Relative_have',
#        'Living_standard_change', 'Enough_food', 'Enough_shelter',
#        'Well_rested', 'Respected',
#        ...
#        'Corruption_government_shap', 'Performance_leadership_shap',
#        'Gender_female_shap', 'Age_shap', 'Marital_status_shap',
#        'Employment_shap', 'Children_under15_shap', 'Feeling_income_shap',
#        'Income_level_shap', 'COUNTRY_ISO3_shap'],
#       dtype='object', length=127)
